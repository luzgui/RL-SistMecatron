# %%
# %pwd
# Out:
# '/home/acr/Documents/Projeto Sistemas Mecatrónicos/RL-SistMecatron/Resultados e Código para Relatório'

# %% [markdown]
# # Runs on Python 3.9. Keras RL doesn't run on python 3.7

# %% [markdown]
# # Building our own scenario

# %% [markdown]
# Build a reinforcement learning model to adjust the temperature automatically to get in the optimal range

# %% [markdown]
# Optimal temperature: Between 37 and 39 degrees
# Shower Length: 60 seconds
# Actions: Turn down, Leave, Turn up
# Task: Build a model that keeps us in the optimal range for as long as possible

# %% [markdown]
# # Install Dependencies

# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.3.0 (from versions: 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.7.0rc0, 2.7.0rc1, 2.7.0)
# ERROR: No matching distribution found for tensorflow==2.3.0
# Requirement already satisfied: gym in /home/acr/anaconda3/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from gym) (1.20.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: keras in /home/acr/anaconda3/lib/python3.9/site-packages (2.7.0)
# Requirement already satisfied: keras-rl2 in /home/acr/anaconda3/lib/python3.9/site-packages (1.0.5)
# Requirement already satisfied: tensorflow in /home/acr/anaconda3/lib/python3.9/site-packages (from keras-rl2) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.37.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.42.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (12.0.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: numpy>=1.14.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.10.0.2)
# Requirement already satisfied: six>=1.12.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.19.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.22.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (3.3.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/acr/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (3.1.1)

# %% [markdown]
# # Creating a random environment

# %% [markdown]
# #### The goal is to balance the pole up, moving the cart to the left or right . For each step it takes a point, for a maximum of 200 points

# %%
from gym import Env # Allows us to build our environment on top of it
from gym import spaces
from gym.spaces import Discrete, Box # Allows us to define the actions and the states of our environment
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# %%
class ShowerEnv(Env): # By passing Env to the showerEnv class we are inheriting the methods and properties from the OpenAI gym environment class
    def __init__(self): # We will be initializing the actions we can take, our observation space, the space, the temperature and the shower length 
        # Actions we can take, down, stay, up
        self.action_space=Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100])) # Box allows to gave a whole range of spaces
        # Set start temp (As in real life, the shower's water starts cold)
        self.state = 15 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60*5 # 10 minutes=10*60 seconds
        
    def step(self, action): # Defines what we do whenever we take actions
        # Aplly action
        # As the action is 0,1 or 2, as we subtract 1 when temperature decreases is -1, when it stays the same is 0 and when it increases is +1
        # 0-1=-1, 1-1=0, 2-1=1
        self.state += action -1
        # Reduce shower length by 1 second
        self.shower_length -= 1
        
        #Calculate reward
        # If water is 38 it gives a reward of 2, if it is 37 or 29 it gives a reward of 1
        if self.state>= 37 and self.state<=39:
            reward= (2-abs(38-self.state))*6
        # The negative rewards will be greater if the colder the water is and the hotter the water is 
        elif self.state < 37:
            reward=-(37-self.state)*2
        elif self.state > 39:
            reward = -(self.state-39)*2
        
        # Check if shower is done
        if self.shower_length <=0 :
            done = True
        else:
            done = False                
        
        # Apply temperature noise
#         self.state+=random.randint(-2,2)
        # Set placeholder for info
        info= {}
        
        # Return step information
        return self.state, reward, done, info # self.state is the temperature
    
    def render(self): # Visualizations
        # Implement visualization
        pass
    def reset(self):
        # Reset shower temperature
        self.state = 15 +random.randint(-3,3)
        # Reset shower time
        self.shower_length = 60*5
        return self.state

# %%
env = ShowerEnv()
# Out:
# /home/acr/anaconda3/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
env.step(1)[0]
# Out:
# 13

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space.high[0]
# Out:
# 100.0

# %%
env.observation_space.sample()
# Out:
# array([68.40295], dtype=float32)

# %% [markdown]
# #### Now we're just setting some random episodes where there is no learning from each of the episodes

# %%
obs = env.reset()

print(env.observation_space)
print(env.action_space)
print(env.action_space.sample())
print()

plt.figure(figsize=(15,7))
episodes = 10
for episode in range(1,episodes+1):
  state=env.reset()
  done=False
  score=0
  Temp_plot=[]

  while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    Temp_plot.append(obs)
    score+=reward
    info = info
    
  plt.plot(Temp_plot, label = 'Episode {}'.format(episode))
  plt.legend()
  print('Episode:{} Score: {} '.format(episode, round(score,0)))
plt.show
# Out:
# Box([0.], [100.], (1,), float32)
# Discrete(3)
# 2
#
# Episode:1 Score: -15572
# Episode:2 Score: -9456
# Episode:3 Score: -9434
# Episode:4 Score: -13330
# Episode:5 Score: -12242
# Episode:6 Score: -4566
# Episode:7 Score: -28772
# Episode:8 Score: -10998
# Episode:9 Score: -2918
# Episode:10 Score: -18064
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# help(env.step)

# %% [markdown]
# # Create a Deep Learning Model with Keras

# %% [markdown]
# #### Ideally we want to take the score of each episode all the way up to 200. The deep RL is going to learn the best action to take in that specific environment to maximize the score

# %%
import numpy as np
import tensorflow  #allows a sequential model with Keras
# It's better to import tensorflow and use sequential than specifically importing the sequential from tensorlfow.keras.model
from tensorflow.keras.layers import Dense, Flatten # We've imported the dense and flattten nodes
from tensorflow.keras.optimizers import Adam # We've imported the optimizer Adam to train the deep learning model
# Out:
# 2021-12-13 13:05:03.598812: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/acr/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2021-12-13 13:05:03.598844: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
states = env.observation_space.shape
actions = env.action_space.n

# %%
states
# Out:
# (1,)

# %%
env.observation_space
# Out:
# Box([0.], [100.], (1,), float32)

# %%
def build_model3layers(states, actions):
  model = tensorflow.keras.Sequential()  # initiating a sequential model
  model.add(Dense(24, activation='relu', input_shape=states))
  model.add(Dense(24, activation='relu'))
  model.add(Dense(24, activation='relu'))
  model.add(Dense(actions, activation='linear')) # This makes sure that the output are the actions. First (or through the top), come the states and lastly comes the acitons
  return model
# This model is fed the states and gets out the actions, and it trains in order to maximize the reward

# %%
del model_a

# %%
model_a = build_model3layers(states,actions)

# %%
model_a.summary() # The final output will have 3 actions. Decreasing, staying the same and increasing the temperature
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 24)                48
#
#  dense_9 (Dense)             (None, 24)                600
#
#  dense_10 (Dense)            (None, 24)                600
#
#  dense_11 (Dense)            (None, 3)                 75
#
# =================================================================
# Total params: 1,323
# Trainable params: 1,323
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Build Agent with Keras-RL

# %%
from rl.agents import DQNAgent # Agent from keras rl, there are several
from rl.policy import BoltzmannQPolicy # There are two types of policies, the value-based rl and policy-based rl. This case will use policy based policy. This is the boltzmann Qpolicy
from rl.memory import SequentialMemory # For the DQNAgent there is the need for some memory, the Sequential memory allow it

# %%
def build_agent3layers(model, actions):
  policy_a = BoltzmannQPolicy()
  memory_a = SequentialMemory(limit=50000, window_length=1)
  dqn = DQNAgent(model=model_a, memory=memory_a, policy=policy_a, 
                 nb_actions=actions, nb_steps_warmup=50, target_model_update=1e-2)
  return dqn

# %%
dqn = build_agent3layers(model_a,actions) # Agent initiated. It knows the model, where it has the environment, and the actions it is allowed to do 
dqn.compile(Adam(learning_rate=1e-3), metrics=['mae']) # Compile the model through optimizer

# %%
# dqn.fit(env, nb_steps=300000, visualize=False, verbose=1)

# The reward should be improved along the intervals

# %%
# dqn.save_weights('dqn_RL_Example_Custom_Scenario_Variations_1action_NoNoise_KerasRL_RewardsTweak_model_300kSteps',overwrite=False)

# %%
dqn.load_weights('dqn_NoNoise_KerasRL_model_300kSteps')

# %% [markdown]
# The model will never hit a perfect run as the we have some noise being applied and the model only allow to having one degree being changed at a time. This is something that could be improved for future research

# %%
print('For the deep learning model with 3 layers.')
scores = dqn.test(env,nb_episodes=100, visualize=False)
print('\nAverage Episode Reward: {}'.format(np.mean(scores.history['episode_reward'])))
# Out:
# For the deep learning model with 3 layers.
# Testing for 100 episodes ...
# /home/acr/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Episode 1: reward: 2824.000, steps: 300
# Episode 2: reward: 3036.000, steps: 300
# Episode 3: reward: 2766.000, steps: 300
# Episode 4: reward: 2824.000, steps: 300
# Episode 5: reward: 2766.000, steps: 300
# Episode 6: reward: 3036.000, steps: 300
# Episode 7: reward: 3036.000, steps: 300
# Episode 8: reward: 2824.000, steps: 300
# Episode 9: reward: 2986.000, steps: 300
# Episode 10: reward: 3036.000, steps: 300
# Episode 11: reward: 2986.000, steps: 300
# Episode 12: reward: 2824.000, steps: 300
# Episode 13: reward: 3036.000, steps: 300
# Episode 14: reward: 2880.000, steps: 300
# Episode 15: reward: 2934.000, steps: 300
# Episode 16: reward: 3036.000, steps: 300
# Episode 17: reward: 2706.000, steps: 300
# Episode 18: reward: 2706.000, steps: 300
# Episode 19: reward: 3036.000, steps: 300
# Episode 20: reward: 2766.000, steps: 300
# Episode 21: reward: 2766.000, steps: 300
# Episode 22: reward: 2706.000, steps: 300
# Episode 23: reward: 2934.000, steps: 300
# Episode 24: reward: 2766.000, steps: 300
# Episode 25: reward: 2706.000, steps: 300
# Episode 26: reward: 2706.000, steps: 300
# Episode 27: reward: 2766.000, steps: 300
# Episode 28: reward: 2824.000, steps: 300
# Episode 29: reward: 2986.000, steps: 300
# Episode 30: reward: 2986.000, steps: 300
# Episode 31: reward: 2880.000, steps: 300
# Episode 32: reward: 3036.000, steps: 300
# Episode 33: reward: 2986.000, steps: 300
# Episode 34: reward: 2706.000, steps: 300
# Episode 35: reward: 2880.000, steps: 300
# Episode 36: reward: 2934.000, steps: 300
# Episode 37: reward: 2706.000, steps: 300
# Episode 38: reward: 2766.000, steps: 300
# Episode 39: reward: 2824.000, steps: 300
# Episode 40: reward: 2880.000, steps: 300
# Episode 41: reward: 2824.000, steps: 300
# Episode 42: reward: 3036.000, steps: 300
# Episode 43: reward: 2766.000, steps: 300
# Episode 44: reward: 2880.000, steps: 300
# Episode 45: reward: 2986.000, steps: 300
# Episode 46: reward: 2824.000, steps: 300
# Episode 47: reward: 2880.000, steps: 300
# Episode 48: reward: 2986.000, steps: 300
# Episode 49: reward: 2706.000, steps: 300
# Episode 50: reward: 2766.000, steps: 300
# Episode 51: reward: 2880.000, steps: 300
# Episode 52: reward: 2824.000, steps: 300
# Episode 53: reward: 2986.000, steps: 300
# Episode 54: reward: 2934.000, steps: 300
# Episode 55: reward: 2766.000, steps: 300
# Episode 56: reward: 2766.000, steps: 300
# Episode 57: reward: 2766.000, steps: 300
# Episode 58: reward: 2824.000, steps: 300
# Episode 59: reward: 2986.000, steps: 300
# Episode 60: reward: 3036.000, steps: 300
# Episode 61: reward: 2934.000, steps: 300
# Episode 62: reward: 3036.000, steps: 300
# Episode 63: reward: 2986.000, steps: 300
# Episode 64: reward: 2986.000, steps: 300
# Episode 65: reward: 2706.000, steps: 300
# Episode 66: reward: 2986.000, steps: 300
# Episode 67: reward: 2824.000, steps: 300
# Episode 68: reward: 3036.000, steps: 300
# Episode 69: reward: 2986.000, steps: 300
# Episode 70: reward: 2986.000, steps: 300
# Episode 71: reward: 2986.000, steps: 300
# Episode 72: reward: 2934.000, steps: 300
# Episode 73: reward: 2706.000, steps: 300
# Episode 74: reward: 2766.000, steps: 300
# Episode 75: reward: 3036.000, steps: 300
# Episode 76: reward: 2706.000, steps: 300
# Episode 77: reward: 3036.000, steps: 300
# Episode 78: reward: 2766.000, steps: 300
# Episode 79: reward: 2824.000, steps: 300
# Episode 80: reward: 2824.000, steps: 300
# Episode 81: reward: 2934.000, steps: 300
# Episode 82: reward: 2880.000, steps: 300
# Episode 83: reward: 2986.000, steps: 300
# Episode 84: reward: 2934.000, steps: 300
# Episode 85: reward: 2934.000, steps: 300
# Episode 86: reward: 2880.000, steps: 300
# Episode 87: reward: 2706.000, steps: 300
# Episode 88: reward: 2934.000, steps: 300
# Episode 89: reward: 2706.000, steps: 300
# Episode 90: reward: 2934.000, steps: 300
# Episode 91: reward: 2934.000, steps: 300
# Episode 92: reward: 2766.000, steps: 300
# Episode 93: reward: 2706.000, steps: 300
# Episode 94: reward: 2824.000, steps: 300
# Episode 95: reward: 2986.000, steps: 300
# Episode 96: reward: 2706.000, steps: 300
# Episode 97: reward: 2824.000, steps: 300
# Episode 98: reward: 2986.000, steps: 300
# Episode 99: reward: 2706.000, steps: 300
# Episode 100: reward: 2986.000, steps: 300
#
# Average Episode Reward: 2875.12

# %%
plt.figure(figsize=(12,5))

episodes =1
for episode in range(1,episodes+1):
  obs=env.reset()
  done=False
  state_batch = []
  reward_batch = []
  action_batch = []
  total_rewards = 0
  total_rewards_list= []
  step = 0
    
  while not done:
    step+=1
    action = dqn.forward(obs)
    print('\nState:',obs)
    print("Action: ", action-1)
    action_batch.append(action-1)
    obs, rewards, done, info = env.step(action)
    print('State', obs, 'reward=', rewards, 'done=', done)
    state_batch.append(obs)
    reward_batch.append(rewards)
    total_rewards += rewards
    total_rewards_list.append(total_rewards)
    print('Sum of rewards:', total_rewards)
    print('Step:', step)
 
  plt.plot(state_batch, label='State Episode {}'.format(episode))
  plt.plot(reward_batch,label='Reward Episode {}'.format(episode))
  plt.plot(action_batch, label='Action Episode {}'.format(episode))
#   plt.plot(total_rewards_list, label='Sum of rewards Episode {}'.format(episode))
  plt.legend()
plt.show
# Out:
# State: 12
# Action:  1
# State 13 reward= -48 done= False
# Sum of rewards: -48
# Step: 1
#
# State: 13
# Action:  1
# State 14 reward= -46 done= False
# Sum of rewards: -94
# Step: 2
#
# State: 14
# Action:  1
# State 15 reward= -44 done= False
# Sum of rewards: -138
# Step: 3
#
# State: 15
# Action:  1
# State 16 reward= -42 done= False
# Sum of rewards: -180
# Step: 4
#
# State: 16
# Action:  1
# State 17 reward= -40 done= False
# Sum of rewards: -220
# Step: 5
#
# State: 17
# Action:  1
# State 18 reward= -38 done= False
# Sum of rewards: -258
# Step: 6
#
# State: 18
# Action:  1
# State 19 reward= -36 done= False
# Sum of rewards: -294
# Step: 7
#
# State: 19
# Action:  1
# State 20 reward= -34 done= False
# Sum of rewards: -328
# Step: 8
#
# State: 20
# Action:  1
# State 21 reward= -32 done= False
# Sum of rewards: -360
# Step: 9
#
# State: 21
# Action:  1
# State 22 reward= -30 done= False
# Sum of rewards: -390
# Step: 10
#
# State: 22
# Action:  1
# State 23 reward= -28 done= False
# Sum of rewards: -418
# Step: 11
#
# State: 23
# Action:  1
# State 24 reward= -26 done= False
# Sum of rewards: -444
# Step: 12
#
# State: 24
# Action:  1
# State 25 reward= -24 done= False
# Sum of rewards: -468
# Step: 13
#
# State: 25
# Action:  1
# State 26 reward= -22 done= False
# Sum of rewards: -490
# Step: 14
#
# State: 26
# Action:  1
# State 27 reward= -20 done= False
# Sum of rewards: -510
# Step: 15
#
# State: 27
# Action:  1
# State 28 reward= -18 done= False
# Sum of rewards: -528
# Step: 16
#
# State: 28
# Action:  1
# State 29 reward= -16 done= False
# Sum of rewards: -544
# Step: 17
#
# State: 29
# Action:  1
# State 30 reward= -14 done= False
# Sum of rewards: -558
# Step: 18
#
# State: 30
# Action:  1
# State 31 reward= -12 done= False
# Sum of rewards: -570
# Step: 19
#
# State: 31
# Action:  1
# State 32 reward= -10 done= False
# Sum of rewards: -580
# Step: 20
#
# State: 32
# Action:  1
# State 33 reward= -8 done= False
# Sum of rewards: -588
# Step: 21
#
# State: 33
# Action:  1
# State 34 reward= -6 done= False
# Sum of rewards: -594
# Step: 22
#
# State: 34
# Action:  1
# State 35 reward= -4 done= False
# Sum of rewards: -598
# Step: 23
#
# State: 35
# Action:  1
# State 36 reward= -2 done= False
# Sum of rewards: -600
# Step: 24
#
# State: 36
# Action:  1
# State 37 reward= 6 done= False
# Sum of rewards: -594
# Step: 25
#
# State: 37
# Action:  1
# State 38 reward= 12 done= False
# Sum of rewards: -582
# Step: 26
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -570
# Step: 27
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -558
# Step: 28
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -546
# Step: 29
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -534
# Step: 30
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -522
# Step: 31
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -510
# Step: 32
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -498
# Step: 33
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -486
# Step: 34
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -474
# Step: 35
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -462
# Step: 36
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -450
# Step: 37
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -438
# Step: 38
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -426
# Step: 39
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -414
# Step: 40
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -402
# Step: 41
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -390
# Step: 42
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -378
# Step: 43
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -366
# Step: 44
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -354
# Step: 45
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -342
# Step: 46
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -330
# Step: 47
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -318
# Step: 48
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -306
# Step: 49
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -294
# Step: 50
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -282
# Step: 51
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -270
# Step: 52
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -258
# Step: 53
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -246
# Step: 54
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -234
# Step: 55
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -222
# Step: 56
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -210
# Step: 57
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -198
# Step: 58
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -186
# Step: 59
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -174
# Step: 60
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -162
# Step: 61
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -150
# Step: 62
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -138
# Step: 63
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -126
# Step: 64
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -114
# Step: 65
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -102
# Step: 66
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -90
# Step: 67
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -78
# Step: 68
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -66
# Step: 69
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -54
# Step: 70
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -42
# Step: 71
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -30
# Step: 72
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -18
# Step: 73
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: -6
# Step: 74
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 6
# Step: 75
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 18
# Step: 76
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 30
# Step: 77
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 42
# Step: 78
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 54
# Step: 79
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 66
# Step: 80
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 78
# Step: 81
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 90
# Step: 82
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 102
# Step: 83
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 114
# Step: 84
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 126
# Step: 85
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 138
# Step: 86
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 150
# Step: 87
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 162
# Step: 88
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 174
# Step: 89
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 186
# Step: 90
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 198
# Step: 91
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 210
# Step: 92
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 222
# Step: 93
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 234
# Step: 94
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 246
# Step: 95
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 258
# Step: 96
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 270
# Step: 97
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 282
# Step: 98
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 294
# Step: 99
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 306
# Step: 100
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 318
# Step: 101
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 330
# Step: 102
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 342
# Step: 103
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 354
# Step: 104
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 366
# Step: 105
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 378
# Step: 106
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 390
# Step: 107
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 402
# Step: 108
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 414
# Step: 109
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 426
# Step: 110
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 438
# Step: 111
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 450
# Step: 112
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 462
# Step: 113
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 474
# Step: 114
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 486
# Step: 115
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 498
# Step: 116
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 510
# Step: 117
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 522
# Step: 118
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 534
# Step: 119
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 546
# Step: 120
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 558
# Step: 121
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 570
# Step: 122
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 582
# Step: 123
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 594
# Step: 124
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 606
# Step: 125
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 618
# Step: 126
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 630
# Step: 127
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 642
# Step: 128
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 654
# Step: 129
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 666
# Step: 130
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 678
# Step: 131
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 690
# Step: 132
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 702
# Step: 133
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 714
# Step: 134
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 726
# Step: 135
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 738
# Step: 136
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 750
# Step: 137
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 762
# Step: 138
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 774
# Step: 139
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 786
# Step: 140
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 798
# Step: 141
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 810
# Step: 142
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 822
# Step: 143
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 834
# Step: 144
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 846
# Step: 145
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 858
# Step: 146
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 870
# Step: 147
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 882
# Step: 148
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 894
# Step: 149
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 906
# Step: 150
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 918
# Step: 151
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 930
# Step: 152
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 942
# Step: 153
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 954
# Step: 154
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 966
# Step: 155
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 978
# Step: 156
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 990
# Step: 157
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1002
# Step: 158
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1014
# Step: 159
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1026
# Step: 160
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1038
# Step: 161
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1050
# Step: 162
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1062
# Step: 163
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1074
# Step: 164
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1086
# Step: 165
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1098
# Step: 166
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1110
# Step: 167
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1122
# Step: 168
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1134
# Step: 169
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1146
# Step: 170
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1158
# Step: 171
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1170
# Step: 172
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1182
# Step: 173
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1194
# Step: 174
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1206
# Step: 175
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1218
# Step: 176
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1230
# Step: 177
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1242
# Step: 178
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1254
# Step: 179
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1266
# Step: 180
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1278
# Step: 181
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1290
# Step: 182
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1302
# Step: 183
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1314
# Step: 184
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1326
# Step: 185
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1338
# Step: 186
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1350
# Step: 187
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1362
# Step: 188
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1374
# Step: 189
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1386
# Step: 190
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1398
# Step: 191
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1410
# Step: 192
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1422
# Step: 193
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1434
# Step: 194
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1446
# Step: 195
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1458
# Step: 196
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1470
# Step: 197
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1482
# Step: 198
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1494
# Step: 199
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1506
# Step: 200
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1518
# Step: 201
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1530
# Step: 202
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1542
# Step: 203
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1554
# Step: 204
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1566
# Step: 205
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1578
# Step: 206
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1590
# Step: 207
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1602
# Step: 208
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1614
# Step: 209
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1626
# Step: 210
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1638
# Step: 211
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1650
# Step: 212
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1662
# Step: 213
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1674
# Step: 214
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1686
# Step: 215
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1698
# Step: 216
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1710
# Step: 217
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1722
# Step: 218
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1734
# Step: 219
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1746
# Step: 220
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1758
# Step: 221
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1770
# Step: 222
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1782
# Step: 223
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1794
# Step: 224
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1806
# Step: 225
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1818
# Step: 226
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1830
# Step: 227
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1842
# Step: 228
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1854
# Step: 229
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1866
# Step: 230
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1878
# Step: 231
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1890
# Step: 232
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1902
# Step: 233
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1914
# Step: 234
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1926
# Step: 235
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1938
# Step: 236
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1950
# Step: 237
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1962
# Step: 238
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1974
# Step: 239
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1986
# Step: 240
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 1998
# Step: 241
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2010
# Step: 242
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2022
# Step: 243
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2034
# Step: 244
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2046
# Step: 245
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2058
# Step: 246
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2070
# Step: 247
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2082
# Step: 248
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2094
# Step: 249
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2106
# Step: 250
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2118
# Step: 251
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2130
# Step: 252
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2142
# Step: 253
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2154
# Step: 254
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2166
# Step: 255
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2178
# Step: 256
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2190
# Step: 257
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2202
# Step: 258
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2214
# Step: 259
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2226
# Step: 260
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2238
# Step: 261
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2250
# Step: 262
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2262
# Step: 263
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2274
# Step: 264
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2286
# Step: 265
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2298
# Step: 266
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2310
# Step: 267
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2322
# Step: 268
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2334
# Step: 269
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2346
# Step: 270
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2358
# Step: 271
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2370
# Step: 272
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2382
# Step: 273
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2394
# Step: 274
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2406
# Step: 275
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2418
# Step: 276
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2430
# Step: 277
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2442
# Step: 278
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2454
# Step: 279
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2466
# Step: 280
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2478
# Step: 281
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2490
# Step: 282
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2502
# Step: 283
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2514
# Step: 284
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2526
# Step: 285
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2538
# Step: 286
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2550
# Step: 287
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2562
# Step: 288
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2574
# Step: 289
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2586
# Step: 290
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2598
# Step: 291
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2610
# Step: 292
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2622
# Step: 293
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2634
# Step: 294
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2646
# Step: 295
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2658
# Step: 296
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2670
# Step: 297
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2682
# Step: 298
#
# State: 38
# Action:  0
# State 38 reward= 12 done= False
# Sum of rewards: 2694
# Step: 299
#
# State: 38
# Action:  0
# State 38 reward= 12 done= True
# Sum of rewards: 2706
# Step: 300
# <function matplotlib.pyplot.show(close=None, block=None)>

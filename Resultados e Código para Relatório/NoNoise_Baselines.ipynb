# %%
# %pwd
# Out:
# '/home/acr/Documents/Projeto Sistemas Mecatrónicos/RL-SistMecatron/Resultados e Código para Relatório'

# %% [markdown]
# # Only runs on Python 3.7 because of the stableBaselines

# %% [markdown]
# # Building our own scenario

# %% [markdown]
# Build a reinforcement learning model to adjust the temperature automatically to get in the optimal range

# %% [markdown]
# Optimal temperature: Between 37 and 39 degrees
# Shower Length: 60 seconds
# Actions: Turn down, Leave, Turn up
# Task: Build a model that keeps us in the optimal range for as long as possible

# %% [markdown]
# # Install Dependencies

# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# !pip install tensorflow-gpu==2.3.0 
# !pip install stable_baselines 
# !pip install gym
# !conda install swig -y # needed to build Box2D in the pip install
# !pip install box2d-py # a repackaged version of pybox2d
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.3.0 (from versions: 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.7.0rc0, 2.7.0rc1, 2.7.0)
# ERROR: No matching distribution found for tensorflow==2.3.0
# Requirement already satisfied: gym in /home/acr/anaconda3/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from gym) (1.20.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: keras in /home/acr/anaconda3/lib/python3.9/site-packages (2.7.0)
# Requirement already satisfied: keras-rl2 in /home/acr/anaconda3/lib/python3.9/site-packages (1.0.5)
# Requirement already satisfied: tensorflow in /home/acr/anaconda3/lib/python3.9/site-packages (from keras-rl2) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.37.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.42.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (12.0.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: numpy>=1.14.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.10.0.2)
# Requirement already satisfied: six>=1.12.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.19.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.22.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/acr/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (3.3.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/acr/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/acr/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/acr/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (3.1.1)

# %% [markdown]
# # Creating a random environment

# %% [markdown]
# #### The goal is to balance the pole up, moving the cart to the left or right . For each step it takes a point, for a maximum of 200 points

# %%
from gym import Env # Allows us to build our environment on top of it
from gym import spaces
from gym.spaces import Discrete, Box # Allows us to define the actions and the states of our environment
import numpy as np
import random
import time
import matplotlib.pyplot as plt
# Out:
# /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
class ShowerEnv(Env): # By passing Env to the showerEnv class we are inheriting the methods and properties from the OpenAI gym environment class
    metadata = {'render.modes': ['console']}
    
    def __init__(self): # We will be initializing the actions we can take, our observation space, the space, the temperature and the shower length 
        super(ShowerEnv,self).__init__()
        # Actions we can take, down, stay, up
        self.action_space=spaces.Discrete(3)
        # Temperature array
        self.observation_space = Box(low=0, high=100, shape=(1,), dtype=np.float32) # Box allows to gave a whole range of spaces
        # Set start temp (As in real life, the shower's water starts cold)
        self.state = 15 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60*5 # 10 minutes=10*60 seconds

    def reset(self):
        # Reset shower temperature
        self.state = 15 +random.randint(-3,3)
        # Reset shower time
        self.shower_length = 60*5
        return np.array([self.state]).astype(np.float32)
    
    def step(self, action): # Defines what we do whenever we take actions
        # Aplly action
        # As the action is 0,1 or 2, as we subtract 1 when temperature decreases is -1, when it stays the same is 0 and when it increases is +1
        # 0-1=-1, 1-1=0, 2-1=1
        self.state += action -1
        # Reduce shower length by 1 second
        self.shower_length -= 1
        
        #Calculate reward
        # If water is 38 it gives a reward of 2, if it is 37 or 29 it gives a reward of 1
        if self.state>= 37 and self.state<=39:
            reward= (2-abs(38-self.state))*6
        # The negative rewards will be greater if the colder the water is and the hotter the water is 
        elif self.state < 37:
            reward=-(37-self.state)*2
        elif self.state > 39:
            reward = -(self.state-39)*2
        
        # Check if shower is done
        if self.shower_length <=0 :
            done = True
        else:
            done = False                
        
        # Apply temperature noise
#         self.state+=random.randint(-2,2)
        # Set placeholder for info
        info= {}
        
        # Return step information
        return np.array([self.state]).astype(np.float32), reward, done, info # self.state is the temperature
    
    def render(self): # Visualizations
        # Implement visualization
        pass
    
    def close(self):
        pass

# %%
env = ShowerEnv()

# %%
env.step(1)[0]
# Out:
# array([14.], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 2

# %%
env.observation_space.high[0]
# Out:
# 100.0

# %%
env.observation_space.sample()
# Out:
# array([39.381714], dtype=float32)

# %% [markdown]
# #### Now we're just setting some random episodes where there is no learning from each of the episodes

# %%
obs = env.reset()

print(env.observation_space)
print(env.action_space)
print(env.action_space.sample())
print()

plt.figure(figsize=(15,8))
episodes = 10
for episode in range(1,episodes+1):
  state=env.reset()
  done=False
  score=0
  Temp_plot=[]

  while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    Temp_plot.append(obs)
    score+=reward
    info = info
    
  plt.plot(Temp_plot, label = 'Episode {}'.format(episode))
  plt.legend()
  plt.title("Evolution of the Temperature", fontsize =30)
  plt.xlabel("Seconds (s)", fontsize =20)
  plt.ylabel("Temperature (ºC)", fontsize =20)
  print('Episode:{} Score: {} '.format(episode, round(score,0)))
plt.show
# Out:
# Box([0.], [100.], (1,), float32)
# Discrete(3)
# 1
#
# Episode:1 Score: -12780
# Episode:2 Score: -14982
# Episode:3 Score: -11208
# Episode:4 Score: -20440
# Episode:5 Score: -2964
# Episode:6 Score: -11438
# Episode:7 Score: -7334
# Episode:8 Score: -10442
# Episode:9 Score: -14294
# Episode:10 Score: -9196
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Build Agent with StableBaselines

# %%
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.deepq.policies import MlpPolicy
from stable_baselines import DQN
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.cmd_util import make_vec_env
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %% [markdown]
# Checking if the environment follows the gym interface

# %%
# It will check your custom environment and output additional warnings if needed
check_env(env, warn=True)

# %%
env = make_vec_env(lambda: env, n_envs=1)

# %%
model1 = DQN('MlpPolicy', env, verbose=1).learn(15000)
# Out:
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/dqn.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:358: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:359: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/policies.py:109: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:147: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:149: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:372: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:372: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:372: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:415: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:449: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/acr/anaconda3/envs/p37workshop/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:322: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.

# %%
episodes =1
for episode in range(1,episodes+1):
  obs=env.reset()
  done=False
  state_batch = []
  reward_batch = []
  action_batch = []
  total_rewards = 0
  total_rewards_list= []
  step = 0
    
  while not done:
    step+=1
    action, obs = model1.predict(obs)
    print('\nState:',obs)
    print("Action: ", action[0]-1)
    action_batch.append(action-1)
    obs, rewards, done, info = env.step(action)
    print('State', obs[0][0], 'reward=', rewards[0], 'done=', done)
    state_batch.append(obs[0][0])
    reward_batch.append(rewards)
    total_rewards += rewards
    total_rewards_list.append(total_rewards[0])
    print('Sum of rewards:', total_rewards[0])
    print('Step:', step)

  plt.figure(figsize=(15,8))  
  plt.plot(state_batch[:-1], label='State Episode {}'.format(episode))
  plt.plot(reward_batch,label='Reward Episode {}'.format(episode))
  plt.plot(action_batch, label='Action Episode {}'.format(episode))
#   plt.plot(total_rewards_list, label='Sum of rewards Episode {}'.format(episode))
  plt.title("Evolution of the temperature, rewards and actions", fontsize =25)
  plt.xlabel("Seconds (s)", fontsize =20)
#   plt.ylabel("Temperature (ºC)", fontsize =20)
  plt.legend()
plt.show
# Out:
# State: None
# Action:  1
# State 19.0 reward= -36.0 done= [False]
# Sum of rewards: -36.0
# Step: 1
#
# State: None
# Action:  1
# State 20.0 reward= -34.0 done= [False]
# Sum of rewards: -70.0
# Step: 2
#
# State: None
# Action:  1
# State 21.0 reward= -32.0 done= [False]
# Sum of rewards: -102.0
# Step: 3
#
# State: None
# Action:  1
# State 22.0 reward= -30.0 done= [False]
# Sum of rewards: -132.0
# Step: 4
#
# State: None
# Action:  1
# State 23.0 reward= -28.0 done= [False]
# Sum of rewards: -160.0
# Step: 5
#
# State: None
# Action:  1
# State 24.0 reward= -26.0 done= [False]
# Sum of rewards: -186.0
# Step: 6
#
# State: None
# Action:  1
# State 25.0 reward= -24.0 done= [False]
# Sum of rewards: -210.0
# Step: 7
#
# State: None
# Action:  1
# State 26.0 reward= -22.0 done= [False]
# Sum of rewards: -232.0
# Step: 8
#
# State: None
# Action:  1
# State 27.0 reward= -20.0 done= [False]
# Sum of rewards: -252.0
# Step: 9
#
# State: None
# Action:  1
# State 28.0 reward= -18.0 done= [False]
# Sum of rewards: -270.0
# Step: 10
#
# State: None
# Action:  1
# State 29.0 reward= -16.0 done= [False]
# Sum of rewards: -286.0
# Step: 11
#
# State: None
# Action:  1
# State 30.0 reward= -14.0 done= [False]
# Sum of rewards: -300.0
# Step: 12
#
# State: None
# Action:  1
# State 31.0 reward= -12.0 done= [False]
# Sum of rewards: -312.0
# Step: 13
#
# State: None
# Action:  1
# State 32.0 reward= -10.0 done= [False]
# Sum of rewards: -322.0
# Step: 14
#
# State: None
# Action:  1
# State 33.0 reward= -8.0 done= [False]
# Sum of rewards: -330.0
# Step: 15
#
# State: None
# Action:  1
# State 34.0 reward= -6.0 done= [False]
# Sum of rewards: -336.0
# Step: 16
#
# State: None
# Action:  1
# State 35.0 reward= -4.0 done= [False]
# Sum of rewards: -340.0
# Step: 17
#
# State: None
# Action:  1
# State 36.0 reward= -2.0 done= [False]
# Sum of rewards: -342.0
# Step: 18
#
# State: None
# Action:  1
# State 37.0 reward= 6.0 done= [False]
# Sum of rewards: -336.0
# Step: 19
#
# State: None
# Action:  1
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -324.0
# Step: 20
#
# State: None
# Action:  1
# State 39.0 reward= 6.0 done= [False]
# Sum of rewards: -318.0
# Step: 21
#
# State: None
# Action:  1
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -320.0
# Step: 22
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -322.0
# Step: 23
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -324.0
# Step: 24
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -326.0
# Step: 25
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -328.0
# Step: 26
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -330.0
# Step: 27
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -332.0
# Step: 28
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -334.0
# Step: 29
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -336.0
# Step: 30
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -338.0
# Step: 31
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -340.0
# Step: 32
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -342.0
# Step: 33
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -344.0
# Step: 34
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -346.0
# Step: 35
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -348.0
# Step: 36
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -350.0
# Step: 37
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -352.0
# Step: 38
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -354.0
# Step: 39
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -356.0
# Step: 40
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -358.0
# Step: 41
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -360.0
# Step: 42
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -362.0
# Step: 43
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -364.0
# Step: 44
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -366.0
# Step: 45
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -368.0
# Step: 46
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -370.0
# Step: 47
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -372.0
# Step: 48
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -374.0
# Step: 49
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -376.0
# Step: 50
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -378.0
# Step: 51
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -380.0
# Step: 52
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -382.0
# Step: 53
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -384.0
# Step: 54
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -386.0
# Step: 55
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -388.0
# Step: 56
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -390.0
# Step: 57
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -392.0
# Step: 58
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -394.0
# Step: 59
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -396.0
# Step: 60
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -398.0
# Step: 61
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -400.0
# Step: 62
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -402.0
# Step: 63
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -404.0
# Step: 64
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -406.0
# Step: 65
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -408.0
# Step: 66
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -410.0
# Step: 67
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -412.0
# Step: 68
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -414.0
# Step: 69
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -416.0
# Step: 70
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -418.0
# Step: 71
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -420.0
# Step: 72
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -422.0
# Step: 73
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -424.0
# Step: 74
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -426.0
# Step: 75
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -428.0
# Step: 76
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -430.0
# Step: 77
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -432.0
# Step: 78
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -434.0
# Step: 79
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -436.0
# Step: 80
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -438.0
# Step: 81
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -440.0
# Step: 82
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -442.0
# Step: 83
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -444.0
# Step: 84
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -446.0
# Step: 85
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -448.0
# Step: 86
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -450.0
# Step: 87
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -452.0
# Step: 88
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -454.0
# Step: 89
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -456.0
# Step: 90
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -458.0
# Step: 91
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -460.0
# Step: 92
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -462.0
# Step: 93
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -464.0
# Step: 94
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -466.0
# Step: 95
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -468.0
# Step: 96
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -470.0
# Step: 97
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -472.0
# Step: 98
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -474.0
# Step: 99
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -476.0
# Step: 100
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -478.0
# Step: 101
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -480.0
# Step: 102
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -482.0
# Step: 103
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -484.0
# Step: 104
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -486.0
# Step: 105
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -488.0
# Step: 106
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -490.0
# Step: 107
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -492.0
# Step: 108
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -494.0
# Step: 109
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -496.0
# Step: 110
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -498.0
# Step: 111
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -500.0
# Step: 112
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -502.0
# Step: 113
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -504.0
# Step: 114
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -506.0
# Step: 115
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -508.0
# Step: 116
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -510.0
# Step: 117
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -512.0
# Step: 118
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -514.0
# Step: 119
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -516.0
# Step: 120
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -518.0
# Step: 121
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -520.0
# Step: 122
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -522.0
# Step: 123
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -524.0
# Step: 124
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -526.0
# Step: 125
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -528.0
# Step: 126
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -530.0
# Step: 127
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -532.0
# Step: 128
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -534.0
# Step: 129
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -536.0
# Step: 130
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -538.0
# Step: 131
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -540.0
# Step: 132
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -542.0
# Step: 133
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -544.0
# Step: 134
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -546.0
# Step: 135
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -548.0
# Step: 136
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -550.0
# Step: 137
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -552.0
# Step: 138
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -554.0
# Step: 139
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -556.0
# Step: 140
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -558.0
# Step: 141
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -560.0
# Step: 142
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -562.0
# Step: 143
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -564.0
# Step: 144
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -566.0
# Step: 145
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -568.0
# Step: 146
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -570.0
# Step: 147
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -572.0
# Step: 148
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -574.0
# Step: 149
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -576.0
# Step: 150
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -578.0
# Step: 151
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -580.0
# Step: 152
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -582.0
# Step: 153
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -584.0
# Step: 154
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -586.0
# Step: 155
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -588.0
# Step: 156
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -590.0
# Step: 157
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -592.0
# Step: 158
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -594.0
# Step: 159
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -596.0
# Step: 160
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -598.0
# Step: 161
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -600.0
# Step: 162
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -602.0
# Step: 163
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -604.0
# Step: 164
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -606.0
# Step: 165
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -608.0
# Step: 166
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -610.0
# Step: 167
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -612.0
# Step: 168
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -614.0
# Step: 169
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -616.0
# Step: 170
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -618.0
# Step: 171
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -620.0
# Step: 172
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -622.0
# Step: 173
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -624.0
# Step: 174
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -626.0
# Step: 175
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -628.0
# Step: 176
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -630.0
# Step: 177
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -632.0
# Step: 178
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -634.0
# Step: 179
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -636.0
# Step: 180
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -638.0
# Step: 181
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -640.0
# Step: 182
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -642.0
# Step: 183
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -644.0
# Step: 184
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -646.0
# Step: 185
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -648.0
# Step: 186
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -650.0
# Step: 187
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -652.0
# Step: 188
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -654.0
# Step: 189
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -656.0
# Step: 190
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -658.0
# Step: 191
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -660.0
# Step: 192
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -662.0
# Step: 193
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -664.0
# Step: 194
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -666.0
# Step: 195
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -668.0
# Step: 196
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -670.0
# Step: 197
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -672.0
# Step: 198
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -674.0
# Step: 199
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -676.0
# Step: 200
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -678.0
# Step: 201
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -680.0
# Step: 202
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -682.0
# Step: 203
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -684.0
# Step: 204
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -686.0
# Step: 205
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -688.0
# Step: 206
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -690.0
# Step: 207
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -692.0
# Step: 208
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -694.0
# Step: 209
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -696.0
# Step: 210
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -698.0
# Step: 211
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -700.0
# Step: 212
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -702.0
# Step: 213
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -704.0
# Step: 214
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -706.0
# Step: 215
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -708.0
# Step: 216
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -710.0
# Step: 217
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -712.0
# Step: 218
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -714.0
# Step: 219
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -716.0
# Step: 220
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -718.0
# Step: 221
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -720.0
# Step: 222
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -722.0
# Step: 223
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -724.0
# Step: 224
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -726.0
# Step: 225
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -728.0
# Step: 226
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -730.0
# Step: 227
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -732.0
# Step: 228
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -734.0
# Step: 229
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -736.0
# Step: 230
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -738.0
# Step: 231
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -740.0
# Step: 232
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -742.0
# Step: 233
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -744.0
# Step: 234
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -746.0
# Step: 235
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -748.0
# Step: 236
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -750.0
# Step: 237
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -752.0
# Step: 238
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -754.0
# Step: 239
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -756.0
# Step: 240
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -758.0
# Step: 241
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -760.0
# Step: 242
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -762.0
# Step: 243
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -764.0
# Step: 244
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -766.0
# Step: 245
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -768.0
# Step: 246
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -770.0
# Step: 247
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -772.0
# Step: 248
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -774.0
# Step: 249
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -776.0
# Step: 250
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -778.0
# Step: 251
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -780.0
# Step: 252
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -782.0
# Step: 253
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -784.0
# Step: 254
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -786.0
# Step: 255
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -788.0
# Step: 256
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -790.0
# Step: 257
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -792.0
# Step: 258
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -794.0
# Step: 259
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -796.0
# Step: 260
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -798.0
# Step: 261
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -800.0
# Step: 262
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -802.0
# Step: 263
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -804.0
# Step: 264
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -806.0
# Step: 265
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -808.0
# Step: 266
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -810.0
# Step: 267
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -812.0
# Step: 268
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -814.0
# Step: 269
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -816.0
# Step: 270
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -818.0
# Step: 271
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -820.0
# Step: 272
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -822.0
# Step: 273
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -824.0
# Step: 274
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -826.0
# Step: 275
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -828.0
# Step: 276
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -830.0
# Step: 277
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -832.0
# Step: 278
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -834.0
# Step: 279
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -836.0
# Step: 280
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -838.0
# Step: 281
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -840.0
# Step: 282
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -842.0
# Step: 283
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -844.0
# Step: 284
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -846.0
# Step: 285
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -848.0
# Step: 286
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -850.0
# Step: 287
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -852.0
# Step: 288
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -854.0
# Step: 289
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -856.0
# Step: 290
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -858.0
# Step: 291
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -860.0
# Step: 292
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -862.0
# Step: 293
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -864.0
# Step: 294
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -866.0
# Step: 295
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -868.0
# Step: 296
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -870.0
# Step: 297
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -872.0
# Step: 298
#
# State: None
# Action:  0
# State 40.0 reward= -2.0 done= [False]
# Sum of rewards: -874.0
# Step: 299
#
# State: None
# Action:  0
# State 16.0 reward= -2.0 done= [ True]
# Sum of rewards: -876.0
# Step: 300
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# model2 = DQN('MlpPolicy', env, verbose=1).learn(120000)

# %%
model2 = DQN.load("DQN_NoNoise_Baselines_model_120kSteps", env=env)

# %%
episodes =100
Reward_per_Episode = []
for episode in range(1,episodes+1):
  obs=env.reset()
  done=False
  state_batch = []
  reward_batch = []
  action_batch = []
  total_rewards = 0
  total_rewards_list= []
  step = 0
    
  while not done:
    step+=1
    action, obs = model2.predict(obs)
#     print('\nState:',obs)
#     print("Action: ", action[0]-1)
    action_batch.append(action-1)
    obs, rewards, done, info = env.step(action)
#     print('State', obs[0][0], 'reward=', rewards[0], 'done=', done)
    state_batch.append(obs[0][0])
    reward_batch.append(rewards)
    total_rewards += rewards
    total_rewards_list.append(total_rewards[0])
#     print('Sum of rewards:', total_rewards[0])
#     print('Step:', step)
#   print(total_rewards)
  Reward_per_Episode.append(total_rewards)
  print('Episode: {} Reward: {} Steps: {}'.format(episode, Reward_per_Episode[episode-1][0], step))
print('\nAverage Episode Reward: {}'.format(np.mean(Reward_per_Episode)))
# Out:
# Episode: 1 Reward: 2934.0 Steps: 300
# Episode: 2 Reward: 2986.0 Steps: 300
# Episode: 3 Reward: 2706.0 Steps: 300
# Episode: 4 Reward: 2766.0 Steps: 300
# Episode: 5 Reward: 2880.0 Steps: 300
# Episode: 6 Reward: 3036.0 Steps: 300
# Episode: 7 Reward: 2824.0 Steps: 300
# Episode: 8 Reward: 2986.0 Steps: 300
# Episode: 9 Reward: 2706.0 Steps: 300
# Episode: 10 Reward: 2706.0 Steps: 300
# Episode: 11 Reward: 2880.0 Steps: 300
# Episode: 12 Reward: 3036.0 Steps: 300
# Episode: 13 Reward: 2766.0 Steps: 300
# Episode: 14 Reward: 2986.0 Steps: 300
# Episode: 15 Reward: 2824.0 Steps: 300
# Episode: 16 Reward: 2766.0 Steps: 300
# Episode: 17 Reward: 2706.0 Steps: 300
# Episode: 18 Reward: 2706.0 Steps: 300
# Episode: 19 Reward: 2986.0 Steps: 300
# Episode: 20 Reward: 2880.0 Steps: 300
# Episode: 21 Reward: 2824.0 Steps: 300
# Episode: 22 Reward: 3036.0 Steps: 300
# Episode: 23 Reward: 2766.0 Steps: 300
# Episode: 24 Reward: 2986.0 Steps: 300
# Episode: 25 Reward: 2824.0 Steps: 300
# Episode: 26 Reward: 2986.0 Steps: 300
# Episode: 27 Reward: 2766.0 Steps: 300
# Episode: 28 Reward: 3036.0 Steps: 300
# Episode: 29 Reward: 2880.0 Steps: 300
# Episode: 30 Reward: 2824.0 Steps: 300
# Episode: 31 Reward: 3036.0 Steps: 300
# Episode: 32 Reward: 3036.0 Steps: 300
# Episode: 33 Reward: 2766.0 Steps: 300
# Episode: 34 Reward: 2824.0 Steps: 300
# Episode: 35 Reward: 2766.0 Steps: 300
# Episode: 36 Reward: 2766.0 Steps: 300
# Episode: 37 Reward: 3036.0 Steps: 300
# Episode: 38 Reward: 2880.0 Steps: 300
# Episode: 39 Reward: 2934.0 Steps: 300
# Episode: 40 Reward: 3036.0 Steps: 300
# Episode: 41 Reward: 2706.0 Steps: 300
# Episode: 42 Reward: 2824.0 Steps: 300
# Episode: 43 Reward: 2880.0 Steps: 300
# Episode: 44 Reward: 2880.0 Steps: 300
# Episode: 45 Reward: 3036.0 Steps: 300
# Episode: 46 Reward: 2934.0 Steps: 300
# Episode: 47 Reward: 2766.0 Steps: 300
# Episode: 48 Reward: 2986.0 Steps: 300
# Episode: 49 Reward: 2986.0 Steps: 300
# Episode: 50 Reward: 2880.0 Steps: 300
# Episode: 51 Reward: 2824.0 Steps: 300
# Episode: 52 Reward: 2824.0 Steps: 300
# Episode: 53 Reward: 2824.0 Steps: 300
# Episode: 54 Reward: 2706.0 Steps: 300
# Episode: 55 Reward: 2880.0 Steps: 300
# Episode: 56 Reward: 3036.0 Steps: 300
# Episode: 57 Reward: 2986.0 Steps: 300
# Episode: 58 Reward: 2706.0 Steps: 300
# Episode: 59 Reward: 3036.0 Steps: 300
# Episode: 60 Reward: 3036.0 Steps: 300
# Episode: 61 Reward: 2706.0 Steps: 300
# Episode: 62 Reward: 2986.0 Steps: 300
# Episode: 63 Reward: 2986.0 Steps: 300
# Episode: 64 Reward: 2880.0 Steps: 300
# Episode: 65 Reward: 2934.0 Steps: 300
# Episode: 66 Reward: 2986.0 Steps: 300
# Episode: 67 Reward: 3036.0 Steps: 300
# Episode: 68 Reward: 3036.0 Steps: 300
# Episode: 69 Reward: 2766.0 Steps: 300
# Episode: 70 Reward: 3036.0 Steps: 300
# Episode: 71 Reward: 2934.0 Steps: 300
# Episode: 72 Reward: 2934.0 Steps: 300
# Episode: 73 Reward: 2706.0 Steps: 300
# Episode: 74 Reward: 2706.0 Steps: 300
# Episode: 75 Reward: 3036.0 Steps: 300
# Episode: 76 Reward: 2824.0 Steps: 300
# Episode: 77 Reward: 2880.0 Steps: 300
# Episode: 78 Reward: 2766.0 Steps: 300
# Episode: 79 Reward: 2880.0 Steps: 300
# Episode: 80 Reward: 2986.0 Steps: 300
# Episode: 81 Reward: 2934.0 Steps: 300
# Episode: 82 Reward: 2824.0 Steps: 300
# Episode: 83 Reward: 3036.0 Steps: 300
# Episode: 84 Reward: 3036.0 Steps: 300
# Episode: 85 Reward: 3036.0 Steps: 300
# Episode: 86 Reward: 2934.0 Steps: 300
# Episode: 87 Reward: 2824.0 Steps: 300
# Episode: 88 Reward: 2766.0 Steps: 300
# Episode: 89 Reward: 2934.0 Steps: 300
# Episode: 90 Reward: 2824.0 Steps: 300
# Episode: 91 Reward: 2880.0 Steps: 300
# Episode: 92 Reward: 3036.0 Steps: 300
# Episode: 93 Reward: 2880.0 Steps: 300
# Episode: 94 Reward: 2824.0 Steps: 300
# Episode: 95 Reward: 2706.0 Steps: 300
# Episode: 96 Reward: 3036.0 Steps: 300
# Episode: 97 Reward: 2986.0 Steps: 300
# Episode: 98 Reward: 2706.0 Steps: 300
# Episode: 99 Reward: 2934.0 Steps: 300
# Episode: 100 Reward: 2824.0 Steps: 300
#
# Average Episode Reward: 2887.739990234375

# %%
plt.figure(figsize=(15,8))  

episodes =1
for episode in range(1,episodes+1):
  obs=env.reset()
  done=False
  state_batch = []
  reward_batch = []
  action_batch = []
  total_rewards = 0
  total_rewards_list= []
  step = 0
    
  while not done:
    step+=1
    action, obs = model2.predict(obs)
    print('\nState:',obs)
    print("Action: ", action[0]-1)
    action_batch.append(action-1)
    obs, rewards, done, info = env.step(action)
    print('State', obs[0][0], 'reward=', rewards[0], 'done=', done)
    state_batch.append(obs[0][0])
    reward_batch.append(rewards)
    total_rewards += rewards
    total_rewards_list.append(total_rewards[0])
    print('Sum of rewards:', total_rewards[0])
    print('Step:', step)

  plt.plot(state_batch[:-1], label='State Episode {}'.format(episode))
  plt.plot(reward_batch,label='Reward Episode {}'.format(episode))
  plt.plot(action_batch, label='Action Episode {}'.format(episode))
#   plt.plot(total_rewards_list, label='Sum of rewards Episode {}'.format(episode))
  plt.title("Evolution of the temperature, rewards and actions", fontsize =25)
  plt.xlabel("Seconds (s)", fontsize =20)
#   plt.ylabel("Temperature (ºC)", fontsize =20)
  plt.legend()
plt.show
# Out:
# State: None
# Action:  1
# State 13.0 reward= -48.0 done= [False]
# Sum of rewards: -48.0
# Step: 1
#
# State: None
# Action:  1
# State 14.0 reward= -46.0 done= [False]
# Sum of rewards: -94.0
# Step: 2
#
# State: None
# Action:  1
# State 15.0 reward= -44.0 done= [False]
# Sum of rewards: -138.0
# Step: 3
#
# State: None
# Action:  1
# State 16.0 reward= -42.0 done= [False]
# Sum of rewards: -180.0
# Step: 4
#
# State: None
# Action:  1
# State 17.0 reward= -40.0 done= [False]
# Sum of rewards: -220.0
# Step: 5
#
# State: None
# Action:  1
# State 18.0 reward= -38.0 done= [False]
# Sum of rewards: -258.0
# Step: 6
#
# State: None
# Action:  1
# State 19.0 reward= -36.0 done= [False]
# Sum of rewards: -294.0
# Step: 7
#
# State: None
# Action:  1
# State 20.0 reward= -34.0 done= [False]
# Sum of rewards: -328.0
# Step: 8
#
# State: None
# Action:  1
# State 21.0 reward= -32.0 done= [False]
# Sum of rewards: -360.0
# Step: 9
#
# State: None
# Action:  1
# State 22.0 reward= -30.0 done= [False]
# Sum of rewards: -390.0
# Step: 10
#
# State: None
# Action:  1
# State 23.0 reward= -28.0 done= [False]
# Sum of rewards: -418.0
# Step: 11
#
# State: None
# Action:  1
# State 24.0 reward= -26.0 done= [False]
# Sum of rewards: -444.0
# Step: 12
#
# State: None
# Action:  1
# State 25.0 reward= -24.0 done= [False]
# Sum of rewards: -468.0
# Step: 13
#
# State: None
# Action:  1
# State 26.0 reward= -22.0 done= [False]
# Sum of rewards: -490.0
# Step: 14
#
# State: None
# Action:  1
# State 27.0 reward= -20.0 done= [False]
# Sum of rewards: -510.0
# Step: 15
#
# State: None
# Action:  1
# State 28.0 reward= -18.0 done= [False]
# Sum of rewards: -528.0
# Step: 16
#
# State: None
# Action:  1
# State 29.0 reward= -16.0 done= [False]
# Sum of rewards: -544.0
# Step: 17
#
# State: None
# Action:  1
# State 30.0 reward= -14.0 done= [False]
# Sum of rewards: -558.0
# Step: 18
#
# State: None
# Action:  1
# State 31.0 reward= -12.0 done= [False]
# Sum of rewards: -570.0
# Step: 19
#
# State: None
# Action:  1
# State 32.0 reward= -10.0 done= [False]
# Sum of rewards: -580.0
# Step: 20
#
# State: None
# Action:  1
# State 33.0 reward= -8.0 done= [False]
# Sum of rewards: -588.0
# Step: 21
#
# State: None
# Action:  1
# State 34.0 reward= -6.0 done= [False]
# Sum of rewards: -594.0
# Step: 22
#
# State: None
# Action:  1
# State 35.0 reward= -4.0 done= [False]
# Sum of rewards: -598.0
# Step: 23
#
# State: None
# Action:  1
# State 36.0 reward= -2.0 done= [False]
# Sum of rewards: -600.0
# Step: 24
#
# State: None
# Action:  1
# State 37.0 reward= 6.0 done= [False]
# Sum of rewards: -594.0
# Step: 25
#
# State: None
# Action:  1
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -582.0
# Step: 26
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -570.0
# Step: 27
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -558.0
# Step: 28
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -546.0
# Step: 29
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -534.0
# Step: 30
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -522.0
# Step: 31
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -510.0
# Step: 32
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -498.0
# Step: 33
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -486.0
# Step: 34
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -474.0
# Step: 35
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -462.0
# Step: 36
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -450.0
# Step: 37
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -438.0
# Step: 38
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -426.0
# Step: 39
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -414.0
# Step: 40
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -402.0
# Step: 41
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -390.0
# Step: 42
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -378.0
# Step: 43
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -366.0
# Step: 44
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -354.0
# Step: 45
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -342.0
# Step: 46
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -330.0
# Step: 47
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -318.0
# Step: 48
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -306.0
# Step: 49
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -294.0
# Step: 50
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -282.0
# Step: 51
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -270.0
# Step: 52
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -258.0
# Step: 53
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -246.0
# Step: 54
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -234.0
# Step: 55
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -222.0
# Step: 56
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -210.0
# Step: 57
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -198.0
# Step: 58
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -186.0
# Step: 59
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -174.0
# Step: 60
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -162.0
# Step: 61
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -150.0
# Step: 62
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -138.0
# Step: 63
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -126.0
# Step: 64
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -114.0
# Step: 65
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -102.0
# Step: 66
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -90.0
# Step: 67
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -78.0
# Step: 68
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -66.0
# Step: 69
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -54.0
# Step: 70
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -42.0
# Step: 71
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -30.0
# Step: 72
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -18.0
# Step: 73
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: -6.0
# Step: 74
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 6.0
# Step: 75
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 18.0
# Step: 76
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 30.0
# Step: 77
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 42.0
# Step: 78
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 54.0
# Step: 79
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 66.0
# Step: 80
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 78.0
# Step: 81
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 90.0
# Step: 82
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 102.0
# Step: 83
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 114.0
# Step: 84
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 126.0
# Step: 85
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 138.0
# Step: 86
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 150.0
# Step: 87
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 162.0
# Step: 88
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 174.0
# Step: 89
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 186.0
# Step: 90
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 198.0
# Step: 91
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 210.0
# Step: 92
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 222.0
# Step: 93
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 234.0
# Step: 94
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 246.0
# Step: 95
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 258.0
# Step: 96
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 270.0
# Step: 97
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 282.0
# Step: 98
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 294.0
# Step: 99
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 306.0
# Step: 100
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 318.0
# Step: 101
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 330.0
# Step: 102
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 342.0
# Step: 103
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 354.0
# Step: 104
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 366.0
# Step: 105
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 378.0
# Step: 106
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 390.0
# Step: 107
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 402.0
# Step: 108
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 414.0
# Step: 109
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 426.0
# Step: 110
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 438.0
# Step: 111
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 450.0
# Step: 112
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 462.0
# Step: 113
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 474.0
# Step: 114
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 486.0
# Step: 115
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 498.0
# Step: 116
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 510.0
# Step: 117
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 522.0
# Step: 118
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 534.0
# Step: 119
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 546.0
# Step: 120
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 558.0
# Step: 121
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 570.0
# Step: 122
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 582.0
# Step: 123
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 594.0
# Step: 124
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 606.0
# Step: 125
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 618.0
# Step: 126
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 630.0
# Step: 127
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 642.0
# Step: 128
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 654.0
# Step: 129
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 666.0
# Step: 130
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 678.0
# Step: 131
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 690.0
# Step: 132
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 702.0
# Step: 133
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 714.0
# Step: 134
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 726.0
# Step: 135
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 738.0
# Step: 136
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 750.0
# Step: 137
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 762.0
# Step: 138
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 774.0
# Step: 139
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 786.0
# Step: 140
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 798.0
# Step: 141
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 810.0
# Step: 142
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 822.0
# Step: 143
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 834.0
# Step: 144
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 846.0
# Step: 145
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 858.0
# Step: 146
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 870.0
# Step: 147
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 882.0
# Step: 148
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 894.0
# Step: 149
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 906.0
# Step: 150
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 918.0
# Step: 151
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 930.0
# Step: 152
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 942.0
# Step: 153
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 954.0
# Step: 154
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 966.0
# Step: 155
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 978.0
# Step: 156
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 990.0
# Step: 157
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1002.0
# Step: 158
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1014.0
# Step: 159
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1026.0
# Step: 160
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1038.0
# Step: 161
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1050.0
# Step: 162
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1062.0
# Step: 163
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1074.0
# Step: 164
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1086.0
# Step: 165
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1098.0
# Step: 166
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1110.0
# Step: 167
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1122.0
# Step: 168
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1134.0
# Step: 169
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1146.0
# Step: 170
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1158.0
# Step: 171
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1170.0
# Step: 172
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1182.0
# Step: 173
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1194.0
# Step: 174
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1206.0
# Step: 175
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1218.0
# Step: 176
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1230.0
# Step: 177
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1242.0
# Step: 178
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1254.0
# Step: 179
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1266.0
# Step: 180
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1278.0
# Step: 181
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1290.0
# Step: 182
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1302.0
# Step: 183
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1314.0
# Step: 184
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1326.0
# Step: 185
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1338.0
# Step: 186
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1350.0
# Step: 187
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1362.0
# Step: 188
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1374.0
# Step: 189
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1386.0
# Step: 190
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1398.0
# Step: 191
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1410.0
# Step: 192
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1422.0
# Step: 193
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1434.0
# Step: 194
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1446.0
# Step: 195
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1458.0
# Step: 196
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1470.0
# Step: 197
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1482.0
# Step: 198
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1494.0
# Step: 199
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1506.0
# Step: 200
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1518.0
# Step: 201
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1530.0
# Step: 202
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1542.0
# Step: 203
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1554.0
# Step: 204
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1566.0
# Step: 205
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1578.0
# Step: 206
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1590.0
# Step: 207
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1602.0
# Step: 208
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1614.0
# Step: 209
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1626.0
# Step: 210
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1638.0
# Step: 211
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1650.0
# Step: 212
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1662.0
# Step: 213
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1674.0
# Step: 214
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1686.0
# Step: 215
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1698.0
# Step: 216
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1710.0
# Step: 217
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1722.0
# Step: 218
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1734.0
# Step: 219
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1746.0
# Step: 220
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1758.0
# Step: 221
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1770.0
# Step: 222
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1782.0
# Step: 223
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1794.0
# Step: 224
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1806.0
# Step: 225
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1818.0
# Step: 226
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1830.0
# Step: 227
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1842.0
# Step: 228
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1854.0
# Step: 229
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1866.0
# Step: 230
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1878.0
# Step: 231
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1890.0
# Step: 232
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1902.0
# Step: 233
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1914.0
# Step: 234
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1926.0
# Step: 235
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1938.0
# Step: 236
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1950.0
# Step: 237
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1962.0
# Step: 238
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1974.0
# Step: 239
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1986.0
# Step: 240
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 1998.0
# Step: 241
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2010.0
# Step: 242
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2022.0
# Step: 243
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2034.0
# Step: 244
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2046.0
# Step: 245
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2058.0
# Step: 246
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2070.0
# Step: 247
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2082.0
# Step: 248
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2094.0
# Step: 249
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2106.0
# Step: 250
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2118.0
# Step: 251
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2130.0
# Step: 252
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2142.0
# Step: 253
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2154.0
# Step: 254
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2166.0
# Step: 255
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2178.0
# Step: 256
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2190.0
# Step: 257
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2202.0
# Step: 258
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2214.0
# Step: 259
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2226.0
# Step: 260
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2238.0
# Step: 261
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2250.0
# Step: 262
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2262.0
# Step: 263
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2274.0
# Step: 264
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2286.0
# Step: 265
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2298.0
# Step: 266
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2310.0
# Step: 267
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2322.0
# Step: 268
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2334.0
# Step: 269
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2346.0
# Step: 270
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2358.0
# Step: 271
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2370.0
# Step: 272
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2382.0
# Step: 273
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2394.0
# Step: 274
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2406.0
# Step: 275
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2418.0
# Step: 276
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2430.0
# Step: 277
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2442.0
# Step: 278
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2454.0
# Step: 279
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2466.0
# Step: 280
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2478.0
# Step: 281
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2490.0
# Step: 282
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2502.0
# Step: 283
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2514.0
# Step: 284
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2526.0
# Step: 285
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2538.0
# Step: 286
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2550.0
# Step: 287
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2562.0
# Step: 288
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2574.0
# Step: 289
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2586.0
# Step: 290
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2598.0
# Step: 291
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2610.0
# Step: 292
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2622.0
# Step: 293
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2634.0
# Step: 294
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2646.0
# Step: 295
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2658.0
# Step: 296
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2670.0
# Step: 297
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2682.0
# Step: 298
#
# State: None
# Action:  0
# State 38.0 reward= 12.0 done= [False]
# Sum of rewards: 2694.0
# Step: 299
#
# State: None
# Action:  0
# State 18.0 reward= 12.0 done= [ True]
# Sum of rewards: 2706.0
# Step: 300
# <function matplotlib.pyplot.show(close=None, block=None)>
